# %%
import pandas as pd
from datetime import datetime
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## basic data visualizations

# %%
# downloading the dataset 
df = pd.read_csv('complete_dataset.csv')
df['date'] = df['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))
# df = df[df['date'].apply(lambda x: x.year)==2019].reset_index(drop=True)

# %%
df['school_day'] = df['school_day'].apply(lambda x: 1 if x == 'Y' else 0)
df['holiday'] = df['holiday'].apply(lambda x: 1 if x == 'Y' else 0)

# %%
# variable names
df.columns
# Out:
# Index(['date', 'demand', 'RRP', 'demand_pos_RRP', 'RRP_positive',
#        'demand_neg_RRP', 'RRP_negative', 'frac_at_neg_RRP', 'min_temperature',
#        'max_temperature', 'solar_exposure', 'rainfall', 'school_day',
#        'holiday'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
sns.scatterplot(x='max_temperature', y='demand', data=df)
# Out:
# <AxesSubplot:xlabel='max_temperature', ylabel='demand'>

# %%
sns.scatterplot(x='min_temperature', y='demand', data=df)
# Out:
# <AxesSubplot:xlabel='min_temperature', ylabel='demand'>

# %%
sns.scatterplot(x='solar_exposure', y='demand', data=df)
# Out:
# <AxesSubplot:xlabel='solar_exposure', ylabel='demand'>

# %%
print(df['max_temperature'].isnull().sum())
print(df['solar_exposure'].isnull().sum())
# Out:
# 0
# 1

# %% [markdown]
# ## building MLR

# %%
# model1 : multiple linear regression with max temp, min temp, solar exposure, and holiday
ols_object = smf.ols(formula = 'demand~max_temperature+min_temperature+solar_exposure+holiday+rainfall', data = df)
model1 = ols_object.fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 demand   R-squared:                       0.162
# Model:                            OLS   Adj. R-squared:                  0.160
# Method:                 Least Squares   F-statistic:                     81.02
# Date:                Mon, 27 Feb 2023   Prob (F-statistic):           6.35e-78
# Time:                        00:02:40   Log-Likelihood:                -22826.
# No. Observations:                2102   AIC:                         4.566e+04
# Df Residuals:                    2096   BIC:                         4.570e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        1.249e+05    970.864    128.694      0.000    1.23e+05    1.27e+05
# max_temperature   609.2628     72.702      8.380      0.000     466.687     751.838
# min_temperature  -658.2430     91.415     -7.201      0.000    -837.516    -478.970
# solar_exposure   -595.2569     43.374    -13.724      0.000    -680.318    -510.196
# holiday         -1.693e+04   1467.036    -11.544      0.000   -1.98e+04   -1.41e+04
# rainfall         -216.1322     65.375     -3.306      0.001    -344.339     -87.925
# ==============================================================================
# Omnibus:                       27.810   Durbin-Watson:                   0.723
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.563
# Skew:                           0.281   Prob(JB):                     6.27e-07
# Kurtosis:                       3.103   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize=(24, 8))
plt.subplot(2, 3, 1)
sns.scatterplot(x=model1.fittedvalues, y=model1.resid, color = 'orange')
sns.lineplot(x=[model1.fittedvalues.min(), model1.fittedvalues.max()], y=[0,0], color='blue')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')

plt.subplot(2, 3, 2)
sns.scatterplot(x=df.max_temperature, y=model1.resid, color = 'orange')
sns.lineplot(x=[df.max_temperature.min(), df.max_temperature.max()], y=[0,0], color='blue')
plt.xlabel('Max Temperature')
plt.ylabel('Residuals')

plt.subplot(2, 3, 3)
sns.scatterplot(x=df.min_temperature, y=model1.resid, color = 'orange')
sns.lineplot(x=[df.min_temperature.min(), df.min_temperature.max()], y=[0,0], color='blue')
plt.xlabel('Min Temperature')
plt.ylabel('Residuals')

plt.subplot(2, 3, 4)
sns.scatterplot(x=df.solar_exposure, y=model1.resid, color = 'orange')
sns.lineplot(x=[df.solar_exposure.min(), df.solar_exposure.max()], y=[0,0], color='blue')
plt.xlabel('Solar Exposure')
plt.ylabel('Residuals')

plt.subplot(2, 3, 5)
sns.scatterplot(x=df.rainfall, y=model1.resid, color = 'orange')
sns.lineplot(x=[df.rainfall.min(), df.rainfall.max()], y=[0,0], color='blue')
plt.xlabel('Rainfall')
plt.ylabel('Residuals')

plt.subplot(2, 3, 6)
sns.scatterplot(x=df.holiday, y=model1.resid, color = 'orange')
sns.lineplot(x=[df.holiday.min(), df.holiday.max()], y=[0,0], color='blue')
plt.xlabel('Holiday')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# ### model1 conclusions:
# - y heteroscedastic
# - max temperature quadratic
# - min temperature quadratic

# %%
# model2 : np.log(y) to resovle heterscedasticity
ols_object = smf.ols(formula = 'np.log(demand)~max_temperature+I(max_temperature**2)+min_temperature+I(min_temperature**2)+solar_exposure+holiday', data = df)
model2 = ols_object.fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log(demand)   R-squared:                       0.458
# Model:                            OLS   Adj. R-squared:                  0.457
# Method:                 Least Squares   F-statistic:                     295.6
# Date:                Mon, 27 Feb 2023   Prob (F-statistic):          8.38e-275
# Time:                        00:02:41   Log-Likelihood:                 2212.9
# No. Observations:                2105   AIC:                            -4412.
# Df Residuals:                    2098   BIC:                            -4372.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  12.3818      0.021    597.845      0.000      12.341      12.422
# max_temperature            -0.0472      0.002    -23.029      0.000      -0.051      -0.043
# I(max_temperature ** 2)     0.0010   4.05e-05     25.453      0.000       0.001       0.001
# min_temperature            -0.0281      0.002    -13.608      0.000      -0.032      -0.024
# I(min_temperature ** 2)     0.0011   8.06e-05     13.639      0.000       0.001       0.001
# solar_exposure             -0.0026      0.000     -8.622      0.000      -0.003      -0.002
# holiday                    -0.1235      0.010    -12.486      0.000      -0.143      -0.104
# ==============================================================================
# Omnibus:                       45.605   Durbin-Watson:                   0.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.480
# Skew:                          -0.356   Prob(JB):                     4.90e-11
# Kurtosis:                       2.816   Cond. No.                     6.43e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.43e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
fig = plt.figure(figsize=(24, 8))
plt.subplot(2, 3, 1)
sns.scatterplot(x=model2.fittedvalues, y=model2.resid, color = 'orange')
sns.lineplot(x=[model2.fittedvalues.min(), model2.fittedvalues.max()], y=[0,0], color='blue')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')

plt.subplot(2, 3, 2)
sns.scatterplot(x=df.max_temperature, y=model2.resid, color = 'orange')
sns.lineplot(x=[df.max_temperature.min(), df.max_temperature.max()], y=[0,0], color='blue')
plt.xlabel('Max Temperature')
plt.ylabel('Residuals')

plt.subplot(2, 3, 3)
sns.scatterplot(x=df.min_temperature, y=model2.resid, color = 'orange')
sns.lineplot(x=[df.min_temperature.min(), df.min_temperature.max()], y=[0,0], color='blue')
plt.xlabel('Min Temperature')
plt.ylabel('Residuals')

plt.subplot(2, 3, 4)
sns.scatterplot(x=df.solar_exposure, y=model2.resid, color = 'orange')
sns.lineplot(x=[df.solar_exposure.min(), df.solar_exposure.max()], y=[0,0], color='blue')
plt.xlabel('Solar Exposure')
plt.ylabel('Residuals')

plt.subplot(2, 3, 5)
sns.scatterplot(x=df.rainfall, y=model2.resid, color = 'orange')
sns.lineplot(x=[df.rainfall.min(), df.rainfall.max()], y=[0,0], color='blue')
plt.xlabel('Rainfall')
plt.ylabel('Residuals')

plt.subplot(2, 3, 6)
sns.scatterplot(x=df.holiday, y=model2.resid, color = 'orange')
sns.lineplot(x=[df.holiday.min(), df.holiday.max()], y=[0,0], color='blue')
plt.xlabel('Holiday')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# ### model 2 conclusions:
# - R-squared significantly better
# - residual plots indicate that linear assumptions have been satisfied

# %% [markdown]
# ## autocorrelation

# %%
sns.lineplot(x='date', y='demand', data=df)
# Out:
# <AxesSubplot:xlabel='date', ylabel='demand'>

# %%
sm.graphics.tsa.plot_pacf(df.demand.squeeze(), lags=10, method="ywm")
plt.show()
# conclusion(s): significant spike at a lag of 1

# %%
# functions for autocorrelation
import numpy.ma as ma
from scipy.stats.stats import pearsonr, normaltest
from scipy.spatial.distance import correlation

def build_model(features):
    X=sm.add_constant(df[df['date']<date][features])
    y=df[df['date']<date]['demand']
    model = sm.OLS(y, X, missing='drop').fit()
    predictions = model.predict(X)
    res = y-predictions
    return model, res

def plt_residual(res):
    plt.plot(range(len(res)), res) 
    plt.ylabel('Residual')
    plt.xlabel('Day')

def plt_residual_lag(res, nlag):
    x=res.values
    y=res.shift(nlag).values
    sns.kdeplot(x,y=y,color='blue',shade=True )
    plt.xlabel('res')
    plt.ylabel("res-lag-{}".format(nlag))
    rho,p=corrcoef(x,y)
    plt.title("n_lag={} hours, correlation={:f}".format(nlag, rho))
    
def plt_acf(res):
    plt.rcParams['figure.figsize'] = [18, 5]
    acorr = sm.tsa.acf(res.dropna(), nlags = len(res.dropna())-1)
    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.plot(acorr)
    ax1.set_ylabel('corr')
    ax1.set_xlabel('n_lag')
    ax1.set_title('Auto Correlation')
    ax2.plot(acorr[:4*7])
    ax2.set_ylabel('corr')
    ax2.set_xlabel('n_lag')
    ax2.set_title('Auto Correlation (4-week zoomed in) ')
    plt.show()
    pd.set_option('display.max_columns', None)
    adf=pd.DataFrame(np.round(acorr[:30], 2).reshape([30, 1] ))
    adf.index.name='day'
    display(adf)
    plt.rcParams['figure.figsize'] = [9, 5]

def corrcoef(x,y):
    a,b=ma.masked_invalid(x),ma.masked_invalid(y)
    msk = (~a.mask & ~b.mask)
    return pearsonr(x[msk],y[msk])[0], normaltest(res, nan_policy='omit')[1]

# %%
df['demand'] = np.log(df['demand'])
df['max_temperature_squared'] = (df['max_temperature'])**2
df['min_temperature_squared'] = (df['min_temperature'])**2

# %%
df.at[df[df['solar_exposure'].isna()].index[0], 'solar_exposure'] = 0

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
X = df[['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday']]
X = add_constant(X)
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns

for i in range(len(X.columns)):
    vif_data.loc[i,'VIF'] = variance_inflation_factor(X.values, i)

print(vif_data)
# Out:
#                    feature         VIF
# 0                    const  125.847443
# 1          max_temperature   48.721772
# 2  max_temperature_squared   42.575362
# 3          min_temperature   23.195049
# 4  min_temperature_squared   22.360798
# 5           solar_exposure    1.663559
# 6                  holiday    1.012090

# %% [markdown]
# ### vif conclusions:
# - max_temperature, max_temperature_squared, min_temperature, and min_temperature_squared have high vif — makes sense since _temperature_squared was dervied from _temperature

# %%
out = model2.outlier_test()

sns.scatterplot(x = (model2.fittedvalues), y=(out.student_resid),color = 'orange')
sns.lineplot(x = [model2.fittedvalues.min(), model2.fittedvalues.max()], y = [0,0], color = 'blue')
plt.xlabel('Fitted values')
plt.ylabel('Studentized Residuals')
# Out:
# Text(0, 0.5, 'Studentized Residuals')

# %%
np.sum((np.abs(out.student_resid)>3))
# Out:
# 4

# %%
from datetime import date, timedelta

sdate = date(2019,1,1)
edate = date(2020,1,1)
all_dates = pd.date_range(sdate, edate-timedelta(days=1), freq='d')

# %%
predictions1 = pd.DataFrame()
sse = 0
for date in all_dates:
    model, residuals = build_model(['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday'])
    subset = df[df['date'] == date]
    temp = model2.predict(sm.add_constant(subset[['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday']]))
    sse += ((np.exp(subset['demand']) - np.exp(temp.values))**2).sum()
    predictions1 = pd.concat([predictions1, temp])

# %%
model, residuals = build_model(['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday'])

# %%
print(model.summary())
plt_residual(residuals)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 demand   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     251.6
# Date:                Tue, 28 Feb 2023   Prob (F-statistic):          2.02e-234
# Time:                        14:23:20   Log-Likelihood:                 1920.8
# No. Observations:                1825   AIC:                            -3828.
# Df Residuals:                    1818   BIC:                            -3789.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      12.3761      0.022    555.066      0.000      12.332      12.420
# max_temperature            -0.0470      0.002    -21.358      0.000      -0.051      -0.043
# max_temperature_squared     0.0010   4.34e-05     23.631      0.000       0.001       0.001
# min_temperature            -0.0262      0.002    -11.765      0.000      -0.031      -0.022
# min_temperature_squared     0.0010   8.58e-05     12.110      0.000       0.001       0.001
# solar_exposure             -0.0027      0.000     -8.548      0.000      -0.003      -0.002
# holiday                    -0.1256      0.011    -11.851      0.000      -0.146      -0.105
# ==============================================================================
# Omnibus:                       43.127   Durbin-Watson:                   1.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.398
# Skew:                          -0.378   Prob(JB):                     1.39e-10
# Kurtosis:                       2.836   Cond. No.                     6.57e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sns.scatterplot(x=df['demand'], y=predictions1[0], color = 'orange')
x_var = np.linspace(min(df['demand']), max(df['demand']))
y_var = x_var
plt.plot(x_var, y_var)
plt.xlabel('Actual Power')
plt.ylabel('Predicted Power')
# Out:
# Text(0, 0.5, 'Predicted Power')

# %%
np.sqrt(sse/365)
# Out:
# 9381.789203954604

# %%
df['demand_lag_1_day']=df['demand'].shift(1)

predictions2 = pd.DataFrame()
sse = 0
for date in all_dates:
    model, residuals = build_model(['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday', 'demand_lag_1_day'])
    subset = df[df['date'] == date]
    temp = model2.predict(sm.add_constant(subset[['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday', 'demand_lag_1_day']]))
    sse += ((np.exp(subset['demand']) - np.exp(temp.values))**2).sum()
    predictions2 = pd.concat([predictions2, temp])

# %%
model, residuals = build_model(['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday', 'demand_lag_1_day'])
print(model.summary())
plt_residual(residuals)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 demand   R-squared:                       0.614
# Model:                            OLS   Adj. R-squared:                  0.612
# Method:                 Least Squares   F-statistic:                     412.2
# Date:                Tue, 28 Feb 2023   Prob (F-statistic):               0.00
# Time:                        14:23:48   Log-Likelihood:                 2236.8
# No. Observations:                1824   AIC:                            -4458.
# Df Residuals:                    1816   BIC:                            -4414.
# Df Model:                           7
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       6.4059      0.218     29.400      0.000       5.979       6.833
# max_temperature            -0.0355      0.002    -18.698      0.000      -0.039      -0.032
# max_temperature_squared     0.0008   3.73e-05     21.615      0.000       0.001       0.001
# min_temperature            -0.0080      0.002     -4.043      0.000      -0.012      -0.004
# min_temperature_squared     0.0002   7.77e-05      3.192      0.001    9.56e-05       0.000
# solar_exposure             -0.0012      0.000     -4.420      0.000      -0.002      -0.001
# holiday                    -0.0843      0.009     -9.260      0.000      -0.102      -0.066
# demand_lag_1_day            0.4892      0.018     27.503      0.000       0.454       0.524
# ==============================================================================
# Omnibus:                       36.921   Durbin-Watson:                   1.499
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.261
# Skew:                          -0.328   Prob(JB):                     8.11e-09
# Kurtosis:                       2.756   Cond. No.                     7.62e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.62e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sns.scatterplot(x=df['demand'], y=predictions2[0], color = 'orange')
x_var = np.linspace(min(df['demand']), max(df['demand']))
y_var = x_var
plt.plot(x_var, y_var)
plt.xlabel('Actual Power')
plt.ylabel('Predicted Power')
# Out:
# Text(0, 0.5, 'Predicted Power')

# %%
np.sqrt(sse/365)
# Out:
# 9381.789203954604

# %%
df['demand_lag_1_week']=df['demand'].shift(7)

predictions3 = pd.DataFrame()
sse = 0
for date in all_dates:
    model, residuals = build_model(['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday', 'demand_lag_1_day', 'demand_lag_1_week'])
    subset = df[df['date'] == date]
    temp = model2.predict(sm.add_constant(subset[['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday', 'demand_lag_1_day', 'demand_lag_1_week']]))
    sse += ((np.exp(subset['demand']) - np.exp(temp.values))**2).sum()
    predictions3 = pd.concat([predictions3, temp])

# %%
model, residuals = build_model(['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday', 'demand_lag_1_day', 'demand_lag_1_week'])
print(model.summary())
plt_residual(residuals)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 demand   R-squared:                       0.737
# Model:                            OLS   Adj. R-squared:                  0.736
# Method:                 Least Squares   F-statistic:                     634.6
# Date:                Tue, 28 Feb 2023   Prob (F-statistic):               0.00
# Time:                        14:24:03   Log-Likelihood:                 2581.6
# No. Observations:                1818   AIC:                            -5145.
# Df Residuals:                    1809   BIC:                            -5096.
# Df Model:                           8
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       3.6982      0.202     18.281      0.000       3.301       4.095
# max_temperature            -0.0326      0.002    -20.674      0.000      -0.036      -0.030
# max_temperature_squared     0.0008   3.11e-05     24.154      0.000       0.001       0.001
# min_temperature            -0.0111      0.002     -6.791      0.000      -0.014      -0.008
# min_temperature_squared     0.0004   6.44e-05      6.674      0.000       0.000       0.001
# solar_exposure             -0.0009      0.000     -4.155      0.000      -0.001      -0.000
# holiday                    -0.1016      0.008    -13.500      0.000      -0.116      -0.087
# demand_lag_1_day            0.3145      0.016     19.768      0.000       0.283       0.346
# demand_lag_1_week           0.4038      0.014     29.078      0.000       0.377       0.431
# ==============================================================================
# Omnibus:                       72.028   Durbin-Watson:                   1.338
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              115.993
# Skew:                          -0.340   Prob(JB):                     6.49e-26
# Kurtosis:                       4.034   Cond. No.                     8.52e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.52e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sns.scatterplot(x=df['demand'], y=predictions3[0], color = 'orange')
x_var = np.linspace(min(df['demand']), max(df['demand']))
y_var = x_var
plt.plot(x_var, y_var)
plt.xlabel('Actual Power')
plt.ylabel('Predicted Power')
# Out:
# Text(0, 0.5, 'Predicted Power')

# %%
np.sqrt(sse/365)
# Out:
# 9381.789203954604

# %%
df['demand_lag_2_week']=df['demand'].shift(14)

predictions4 = pd.DataFrame()
sse = 0
for date in all_dates:
    model, residuals = build_model(['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday', 'demand_lag_1_day', 'demand_lag_1_week', 'demand_lag_2_week'])
    subset = df[df['date'] == date]
    temp = model2.predict(sm.add_constant(subset[['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday', 'demand_lag_1_day']]))
    sse += ((np.exp(subset['demand']) - np.exp(temp.values))**2).sum()
    predictions4 = pd.concat([predictions4, temp])

# %%
model, residuals = build_model(['max_temperature', 'max_temperature_squared', 'min_temperature', 'min_temperature_squared', 'solar_exposure', 'holiday', 'demand_lag_1_day', 'demand_lag_1_week', 'demand_lag_2_week'])
print(model.summary())
plt_residual(residuals)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 demand   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.767
# Method:                 Least Squares   F-statistic:                     664.5
# Date:                Tue, 28 Feb 2023   Prob (F-statistic):               0.00
# Time:                        14:24:14   Log-Likelihood:                 2686.6
# No. Observations:                1811   AIC:                            -5353.
# Df Residuals:                    1801   BIC:                            -5298.
# Df Model:                           9
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       2.8314      0.198     14.290      0.000       2.443       3.220
# max_temperature            -0.0319      0.001    -21.526      0.000      -0.035      -0.029
# max_temperature_squared     0.0007   2.93e-05     25.302      0.000       0.001       0.001
# min_temperature            -0.0112      0.002     -7.241      0.000      -0.014      -0.008
# min_temperature_squared     0.0004   6.07e-05      7.337      0.000       0.000       0.001
# solar_exposure             -0.0009      0.000     -4.325      0.000      -0.001      -0.000
# holiday                    -0.1055      0.007    -14.915      0.000      -0.119      -0.092
# demand_lag_1_day            0.2765      0.015     18.221      0.000       0.247       0.306
# demand_lag_1_week           0.2933      0.015     19.324      0.000       0.264       0.323
# demand_lag_2_week           0.2217      0.015     14.910      0.000       0.193       0.251
# ==============================================================================
# Omnibus:                       42.779   Durbin-Watson:                   1.241
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.529
# Skew:                          -0.165   Prob(JB):                     1.46e-17
# Kurtosis:                       3.958   Cond. No.                     8.86e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.86e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sns.scatterplot(x=df['demand'], y=predictions4[0], color = 'orange')
x_var = np.linspace(min(df['demand']), max(df['demand']))
y_var = x_var
plt.plot(x_var, y_var)
plt.xlabel('Actual Power')
plt.ylabel('Predicted Power')
# Out:
# Text(0, 0.5, 'Predicted Power')

# %%
np.sqrt(sse/365)
# Out:
# 9381.789203954604
